# %%
# %pylab --no-import-all inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15, 6)

from scipy.io import wavfile
from scipy.signal import lfilter, cwt, ricker
from pylab import specgram
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
(fs, s) = wavfile.read('../data/nickyrose.wav')

# %%
plt.plot(s)

# %%
# Plot 200 time samples
plt.plot(s[1000:1200])

# %%
framelen=int(20e-3*fs)
plot = specgram(s,NFFT=framelen, Fs=fs, noverlap=framelen/2)

# %%
from IPython.display import Audio
Audio(data=s, rate=fs, autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Out:
# 10000
